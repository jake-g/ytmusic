# %%
import os
import time
import pandas as pd

# %%
# %%time
from ytmusicapi import YTMusic
yt = YTMusic('../headers_auth.json')

BACKUP_DIR  = '../playlists'
NEW_TRACKS_TSV = os.path.join(BACKUP_DIR, '_tracks_w_meta.tsv') 
CURRENT_TRACKS_TSV = os.path.join(BACKUP_DIR, '_tracks.tsv')
# Out:
# Wall time: 354 ms

# %%
# %%time
i = 0
def get_track_info(row):
    copy_cols=['keywords', 'averageRating', 'viewCount', 'release']
    if type(row['albumId']) == str and 'privately_owned' not in row['albumId']:
        try:
            song = yt.get_song(row.name)
            for col in copy_cols:
                if col in song:
                    row[col] = song[col]
        except Exception as e:
            print('Failed to get track info: %s\n%s' % (e, row))
    return row

unique_tracks = pd.read_csv(CURRENT_TRACKS_TSV, sep='\t', index_col=0)
# tracks_w_meta = unique_tracks.apply(get_track_info, axis=1)

i=0
new_rows = []
for name, row in unique_tracks.iterrows():
    i+=1
    print('(%d/%d): %s - %s - %s' % (i, len(unique_tracks), row['artist'], row['album'], row['title']))
    new_rows.append(get_track_info(row))

pd.DataFrame(new_rows).to_csv(NEW_TRACKS_TSV, sep='\t', header=True)
# Out:
# (1/44298): Nicolas Jaar - Daftside - Beyond
# (2/44298): The Souljazz Orchestra - Inner Fire - Kingdom Come
# (3/44298): Aesop Rock - Plays, Strays & Stays: A Rhymesayers 2018 Recap - Klutz
# (4/44298): Lucky Dragons - Dream Island Laughing Language - Mirror Friends
# (5/44298): Ike And Tina Turner - All the Best - the Hits - Nutbush City Limits
# (6/44298): Nicolas Jaar - Cenizas - Rubble
# (7/44298): Chiddy Bang - Breakfast - Mind Your Manners (feat. Icona Pop)
# (8/44298): Blank Banshee - MEGA - Holograffiti
# (9/44298): Spectator Bird - Given Names - Naomi
# (10/44298): Dido - Still on My Mind - Have to Stay
# (11/44298): Radiohead - Knives Out - Fog
# Wall time: 7.87 s
